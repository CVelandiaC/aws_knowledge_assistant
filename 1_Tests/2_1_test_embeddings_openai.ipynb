# %% [markdown]
# # Generate Embeddings for text
# Author: Cristian Velandia
#
# Creation Date: 2024-03-02
#
# Create embeddings for the vector DB using openai embeddings API

# %%
from openai import OpenAI
from tqdm.auto import tqdm
from time import sleep
import pandas as pd
import json

# %% [markdown]
# ### Load Dataset

# %%
data_path = r"D:\Documents\GitHub\knowledge_pal_assistant\2_outputs\chunks.parquet"
chunks = pd.read_parquet(data_path, engine = "pyarrow")

# %%
chunks.head()
# Out:
#     id                                       page_content  \
# 0  0-0  # AWS::Events::Rule SageMakerPipelineParameter...
# 1  0-1  ## Syntax<a name="aws-properties-events-rule-s...
# 2  0-2  ## Properties<a name="aws-properties-events-ru...
# 3  1-0  # Automating Amazon SageMaker with Amazon Even...
# 4  1-1  ## Training job state change<a name="eventbrid...
#
#                                             metadata  \
# 0  {'Header 1': 'AWS::Events::Rule SageMakerPipel...
# 1  {'Header 1': 'AWS::Events::Rule SageMakerPipel...
# 2  {'Header 1': 'AWS::Events::Rule SageMakerPipel...
# 3  {'Header 1': 'Automating Amazon SageMaker with...
# 4  {'Header 1': 'Automating Amazon SageMaker with...
#
#                                               tokens  \
# 0  [#, AWS, :, :Events, :, :Rule, SageMakerPipeli...
# 1  [#, #, Syntax, <, a, name=, '', aws-properties...
# 2  [#, #, Properties, <, a, name=, '', aws-proper...
# 3  [#, Automating, Amazon, SageMaker, with, Amazo...
# 4  [#, #, Training, job, state, change, <, a, nam...
#
#                                 nostopw_page_content
# 0  # AWS : :Events : :Rule SageMakerPipelineParam...
# 1  # # Syntax < name= '' aws-properties-events-ru...
# 2  # # Properties < name= '' aws-properties-event...
# 3  # Automating Amazon SageMaker Amazon EventBrid...
# 4  # # Training job state change < name= '' event...

# %%
chunks.shape
# Out:
# (1046, 5)

# %%
chunks["token_length"] = chunks["tokens"].apply(lambda x: len(x))
chunks.reset_index(drop = False, inplace = True)

# %% [markdown]
# ### Connect to OpenAI

# %%
# get api keys
creds =json.load(open('personal_creds.json'))

OPENAI_API_KEY = creds["OPENAI_API_KEY"]

# %%
openai_client = OpenAI(api_key=OPENAI_API_KEY)

# %% [markdown]
# ### Generate Embeddings

# %%
# To embed multiple inputs in a single request, pass an array of strings or array of token arrays. The input must not exceed the max input tokens for the model (8192 tokens for text-embedding-ada-002). API limits 200 CPD, 150000 TPM free tier, 3 requests per minute
#chunks["vectors"] = chunks["page_content"].apply(lambda x: openai_client.embeddings.create(input = x, model = "text-embedding-ada-002"))


#Create Batches and request embedings
corpus_size = chunks.shape[0]
counter = 1
batch_size = 5
valid_batch = 0
vect_df = pd.DataFrame()
toggle = False
max_calls = 100 

while corpus_size > 0:
    batch = chunks[(chunks["index"] >= batch_size*(counter-1)) & (chunks["index"] < batch_size*counter)]
    corpus_size -= batch.shape[0]
    text_list = batch["page_content"].to_list()
    total_tokens = batch["token_length"].sum()
    
    if total_tokens <= 8192:
        valid_batch += 1
        print("ammount of valid batches: ", valid_batch)
        valid_ids = batch["id"].tolist()

        #Make sure to not do more than 3 requests per minute, try 10 times 20 secs spaced
        for attempt in range(10):
            try:
                #Call Embeddings API
                embeddings = openai_client.embeddings.create(input = text_list, model = "text-embedding-ada-002",)
            except Exception as error:
                print(type(error).__name__, "-", error, "now sleep")
                if "RPD" in str(error): #handle max requests per day
                    toggle = True
                    break
                else: #handle max requests per minute 
                    sleep(60)
            else:
                print("ok")
                break
        
        vect_df = pd.concat([vect_df, pd.DataFrame.from_dict(dict(zip(valid_ids, [[e.embedding] for e in embeddings.data])), orient='index', columns=["vect"])])

    if toggle or valid_batch >= 100:
        print("Terminating due to max requests exceeded")
        break

        
    
    print("count {}, batch {}, tokens in batch {}, remaining rows {}, vectors generated {}".format(counter, batch.shape[0], total_tokens, corpus_size, vect_df.shape[0]))
        
    counter += 1

valid_batch
# Out:
# ammount of valid batches:  1
# ok
# count 1, batch 5, tokens in batch 1077, remaining rows 1041, vectors generated 5
# ammount of valid batches:  2
# ok
# count 2, batch 5, tokens in batch 1757, remaining rows 1036, vectors generated 10
# ammount of valid batches:  3
# ok
# count 3, batch 5, tokens in batch 1897, remaining rows 1031, vectors generated 15
# ammount of valid batches:  4
# ok
# count 4, batch 5, tokens in batch 1030, remaining rows 1026, vectors generated 20
# ammount of valid batches:  5
# ok
# count 5, batch 5, tokens in batch 777, remaining rows 1021, vectors generated 25
# ammount of valid batches:  6
# ok
# count 6, batch 5, tokens in batch 474, remaining rows 1016, vectors generated 30
# ammount of valid batches:  7
# ok
# count 7, batch 5, tokens in batch 483, remaining rows 1011, vectors generated 35
# ammount of valid batches:  8
# ok
# count 8, batch 5, tokens in batch 804, remaining rows 1006, vectors generated 40
# ammount of valid batches:  9
# ok
# count 9, batch 5, tokens in batch 575, remaining rows 1001, vectors generated 45
# ammount of valid batches:  10
# ok
# count 10, batch 5, tokens in batch 742, remaining rows 996, vectors generated 50
# ammount of valid batches:  11
# ok
# count 11, batch 5, tokens in batch 622, remaining rows 991, vectors generated 55
# ammount of valid batches:  12
# ok
# count 12, batch 5, tokens in batch 663, remaining rows 986, vectors generated 60
# ammount of valid batches:  13
# ok
# count 13, batch 5, tokens in batch 583, remaining rows 981, vectors generated 65
# ammount of valid batches:  14
# ok
# count 14, batch 5, tokens in batch 444, remaining rows 976, vectors generated 70
# ammount of valid batches:  15
# ok
# count 15, batch 5, tokens in batch 776, remaining rows 971, vectors generated 75
# ammount of valid batches:  16
# ok
# count 16, batch 5, tokens in batch 848, remaining rows 966, vectors generated 80
# ammount of valid batches:  17
# ok
# count 17, batch 5, tokens in batch 341, remaining rows 961, vectors generated 85
# ammount of valid batches:  18
# ok
# count 18, batch 5, tokens in batch 345, remaining rows 956, vectors generated 90
# ammount of valid batches:  19
# ok
# count 19, batch 5, tokens in batch 678, remaining rows 951, vectors generated 95
# ammount of valid batches:  20
# ok
# count 20, batch 5, tokens in batch 696, remaining rows 946, vectors generated 100
# ammount of valid batches:  21
# ok
# count 21, batch 5, tokens in batch 535, remaining rows 941, vectors generated 105
# ammount of valid batches:  22
# ok
# count 22, batch 5, tokens in batch 729, remaining rows 936, vectors generated 110
# ammount of valid batches:  23
# ok
# count 23, batch 5, tokens in batch 551, remaining rows 931, vectors generated 115
# ammount of valid batches:  24
# ok
# count 24, batch 5, tokens in batch 730, remaining rows 926, vectors generated 120
# ammount of valid batches:  25
# ok
# count 25, batch 5, tokens in batch 478, remaining rows 921, vectors generated 125
# ammount of valid batches:  26
# ok
# count 26, batch 5, tokens in batch 892, remaining rows 916, vectors generated 130
# ammount of valid batches:  27
# ok
# count 27, batch 5, tokens in batch 580, remaining rows 911, vectors generated 135
# ammount of valid batches:  28
# ok
# count 28, batch 5, tokens in batch 759, remaining rows 906, vectors generated 140
# ammount of valid batches:  29
# ok
# count 29, batch 5, tokens in batch 612, remaining rows 901, vectors generated 145
# ammount of valid batches:  30
# ok
# count 30, batch 5, tokens in batch 980, remaining rows 896, vectors generated 150
# ammount of valid batches:  31
# ok
# count 31, batch 5, tokens in batch 684, remaining rows 891, vectors generated 155
# ammount of valid batches:  32
# ok
# count 32, batch 5, tokens in batch 498, remaining rows 886, vectors generated 160
# ammount of valid batches:  33
# ok
# count 33, batch 5, tokens in batch 547, remaining rows 881, vectors generated 165
# ammount of valid batches:  34
# ok
# count 34, batch 5, tokens in batch 764, remaining rows 876, vectors generated 170
# ammount of valid batches:  35
# ok
# count 35, batch 5, tokens in batch 450, remaining rows 871, vectors generated 175
# ammount of valid batches:  36
# ok
# count 36, batch 5, tokens in batch 545, remaining rows 866, vectors generated 180
# ammount of valid batches:  37
# ok
# count 37, batch 5, tokens in batch 501, remaining rows 861, vectors generated 185
# ammount of valid batches:  38
# ok
# count 38, batch 5, tokens in batch 464, remaining rows 856, vectors generated 190
# ammount of valid batches:  39
# ok
# count 39, batch 5, tokens in batch 1066, remaining rows 851, vectors generated 195
# ammount of valid batches:  40
# ok
# count 40, batch 5, tokens in batch 627, remaining rows 846, vectors generated 200
# ammount of valid batches:  41
# ok
# count 41, batch 5, tokens in batch 1108, remaining rows 841, vectors generated 205
# ammount of valid batches:  42
# ok
# count 42, batch 5, tokens in batch 368, remaining rows 836, vectors generated 210
# ammount of valid batches:  43
# ok
# count 43, batch 5, tokens in batch 644, remaining rows 831, vectors generated 215
# ammount of valid batches:  44
# ok
# count 44, batch 5, tokens in batch 1739, remaining rows 826, vectors generated 220
# ammount of valid batches:  45
# ok
# count 45, batch 5, tokens in batch 501, remaining rows 821, vectors generated 225
# ammount of valid batches:  46
# ok
# count 46, batch 5, tokens in batch 671, remaining rows 816, vectors generated 230
# ammount of valid batches:  47
# ok
# count 47, batch 5, tokens in batch 673, remaining rows 811, vectors generated 235
# ammount of valid batches:  48
# ok
# count 48, batch 5, tokens in batch 626, remaining rows 806, vectors generated 240
# ammount of valid batches:  49
# ok
# count 49, batch 5, tokens in batch 570, remaining rows 801, vectors generated 245
# ammount of valid batches:  50
# ok
# count 50, batch 5, tokens in batch 653, remaining rows 796, vectors generated 250
# ammount of valid batches:  51
# ok
# count 51, batch 5, tokens in batch 620, remaining rows 791, vectors generated 255
# ammount of valid batches:  52
# ok
# count 52, batch 5, tokens in batch 556, remaining rows 786, vectors generated 260
# ammount of valid batches:  53
# ok
# count 53, batch 5, tokens in batch 614, remaining rows 781, vectors generated 265
# ammount of valid batches:  54
# ok
# count 54, batch 5, tokens in batch 565, remaining rows 776, vectors generated 270
# ammount of valid batches:  55
# ok
# count 55, batch 5, tokens in batch 1668, remaining rows 771, vectors generated 275
# ammount of valid batches:  56
# ok
# count 56, batch 5, tokens in batch 1053, remaining rows 766, vectors generated 280
# ammount of valid batches:  57
# ok
# count 57, batch 5, tokens in batch 385, remaining rows 761, vectors generated 285
# ammount of valid batches:  58
# ok
# count 58, batch 5, tokens in batch 555, remaining rows 756, vectors generated 290
# ammount of valid batches:  59
# ok
# count 59, batch 5, tokens in batch 1349, remaining rows 751, vectors generated 295
# ammount of valid batches:  60
# ok
# count 60, batch 5, tokens in batch 394, remaining rows 746, vectors generated 300
# ammount of valid batches:  61
# ok
# count 61, batch 5, tokens in batch 565, remaining rows 741, vectors generated 305
# ammount of valid batches:  62
# ok
# count 62, batch 5, tokens in batch 509, remaining rows 736, vectors generated 310
# ammount of valid batches:  63
# ok
# count 63, batch 5, tokens in batch 383, remaining rows 731, vectors generated 315
# ammount of valid batches:  64
# ok
# count 64, batch 5, tokens in batch 414, remaining rows 726, vectors generated 320
# ammount of valid batches:  65
# ok
# count 65, batch 5, tokens in batch 757, remaining rows 721, vectors generated 325
# ammount of valid batches:  66
# ok
# count 66, batch 5, tokens in batch 789, remaining rows 716, vectors generated 330
# ammount of valid batches:  67
# ok
# count 67, batch 5, tokens in batch 566, remaining rows 711, vectors generated 335
# ammount of valid batches:  68
# ok
# count 68, batch 5, tokens in batch 880, remaining rows 706, vectors generated 340
# ammount of valid batches:  69
# ok
# count 69, batch 5, tokens in batch 694, remaining rows 701, vectors generated 345
# ammount of valid batches:  70
# ok
# count 70, batch 5, tokens in batch 502, remaining rows 696, vectors generated 350
# ammount of valid batches:  71
# ok
# count 71, batch 5, tokens in batch 1100, remaining rows 691, vectors generated 355
# ammount of valid batches:  72
# ok
# count 72, batch 5, tokens in batch 649, remaining rows 686, vectors generated 360
# ammount of valid batches:  73
# ok
# count 73, batch 5, tokens in batch 797, remaining rows 681, vectors generated 365
# ammount of valid batches:  74
# ok
# count 74, batch 5, tokens in batch 366, remaining rows 676, vectors generated 370
# ammount of valid batches:  75
# ok
# count 75, batch 5, tokens in batch 482, remaining rows 671, vectors generated 375
# ammount of valid batches:  76
# ok
# count 76, batch 5, tokens in batch 809, remaining rows 666, vectors generated 380
# ammount of valid batches:  77
# ok
# count 77, batch 5, tokens in batch 655, remaining rows 661, vectors generated 385
# ammount of valid batches:  78
# ok
# count 78, batch 5, tokens in batch 772, remaining rows 656, vectors generated 390
# ammount of valid batches:  79
# ok
# count 79, batch 5, tokens in batch 618, remaining rows 651, vectors generated 395
# ammount of valid batches:  80
# ok
# count 80, batch 5, tokens in batch 570, remaining rows 646, vectors generated 400
# ammount of valid batches:  81
# ok
# count 81, batch 5, tokens in batch 933, remaining rows 641, vectors generated 405
# ammount of valid batches:  82
# ok
# count 82, batch 5, tokens in batch 408, remaining rows 636, vectors generated 410
# ammount of valid batches:  83
# ok
# count 83, batch 5, tokens in batch 470, remaining rows 631, vectors generated 415
# ammount of valid batches:  84
# ok
# count 84, batch 5, tokens in batch 467, remaining rows 626, vectors generated 420
# ammount of valid batches:  85
# ok
# count 85, batch 5, tokens in batch 383, remaining rows 621, vectors generated 425
# ammount of valid batches:  86
# ok
# count 86, batch 5, tokens in batch 927, remaining rows 616, vectors generated 430
# ammount of valid batches:  87
# ok
# count 87, batch 5, tokens in batch 592, remaining rows 611, vectors generated 435
# ammount of valid batches:  88
# ok
# count 88, batch 5, tokens in batch 1010, remaining rows 606, vectors generated 440
# ammount of valid batches:  89
# ok
# count 89, batch 5, tokens in batch 508, remaining rows 601, vectors generated 445
# ammount of valid batches:  90
# ok
# count 90, batch 5, tokens in batch 659, remaining rows 596, vectors generated 450
# ammount of valid batches:  91
# ok
# count 91, batch 5, tokens in batch 492, remaining rows 591, vectors generated 455
# ammount of valid batches:  92
# ok
# count 92, batch 5, tokens in batch 514, remaining rows 586, vectors generated 460
# ammount of valid batches:  93
# ok
# count 93, batch 5, tokens in batch 433, remaining rows 581, vectors generated 465
# ammount of valid batches:  94
# ok
# count 94, batch 5, tokens in batch 806, remaining rows 576, vectors generated 470
# ammount of valid batches:  95
# ok
# count 95, batch 5, tokens in batch 641, remaining rows 571, vectors generated 475
# ammount of valid batches:  96
# ok
# count 96, batch 5, tokens in batch 379, remaining rows 566, vectors generated 480
# ammount of valid batches:  97
# ok
# count 97, batch 5, tokens in batch 685, remaining rows 561, vectors generated 485
# ammount of valid batches:  98
# ok
# count 98, batch 5, tokens in batch 650, remaining rows 556, vectors generated 490
# ammount of valid batches:  99
# ok
# count 99, batch 5, tokens in batch 581, remaining rows 551, vectors generated 495
# ammount of valid batches:  100
# ok
# Terminating due to max requests exceeded
# 100

# %%
vectorized_chunks = chunks.merge(vect_df.reset_index(drop=False), how="inner", left_on="id", right_on="index")

# %%
vectorized_chunks.head()
# Out:
#    index_x   id                                       page_content  \
# 0        0  0-0  # AWS::Events::Rule SageMakerPipelineParameter...
# 1        1  0-1  ## Syntax<a name="aws-properties-events-rule-s...
# 2        2  0-2  ## Properties<a name="aws-properties-events-ru...
# 3        3  1-0  # Automating Amazon SageMaker with Amazon Even...
# 4        4  1-1  ## Training job state change<a name="eventbrid...
#
#                                             metadata  \
# 0  {'Header 1': 'AWS::Events::Rule SageMakerPipel...
# 1  {'Header 1': 'AWS::Events::Rule SageMakerPipel...
# 2  {'Header 1': 'AWS::Events::Rule SageMakerPipel...
# 3  {'Header 1': 'Automating Amazon SageMaker with...
# 4  {'Header 1': 'Automating Amazon SageMaker with...
#
#                                               tokens  \
# 0  [#, AWS, :, :Events, :, :Rule, SageMakerPipeli...
# 1  [#, #, Syntax, <, a, name=, '', aws-properties...
# 2  [#, #, Properties, <, a, name=, '', aws-proper...
# 3  [#, Automating, Amazon, SageMaker, with, Amazo...
# 4  [#, #, Training, job, state, change, <, a, nam...
#
#                                 nostopw_page_content  token_length index_y  \
# 0  # AWS : :Events : :Rule SageMakerPipelineParam...            39     0-0
# 1  # # Syntax < name= '' aws-properties-events-ru...           114     0-1
# 2  # # Properties < name= '' aws-properties-event...           164     0-2
# 3  # Automating Amazon SageMaker Amazon EventBrid...           315     1-0
# 4  # # Training job state change < name= '' event...           445     1-1
#
#                                                 vect
# 0  [-0.036196205765008926, 0.024841105565428734, ...
# 1  [-0.03795338422060013, 0.021498069167137146, 0...
# 2  [-0.03936085104942322, 0.019204849377274513, 0...
# 3  [-0.0347835049033165, -0.01207298319786787, -0...
# 4  [-0.035871874541044235, 0.0021414232905954123,...

# %%
save_folder = "D:\\Documents\GitHub\\knowledge_pal_assistant\\2_outputs\\"
vectorized_chunks.to_parquet(save_folder + "vectors.parquet", index = False, engine = "pyarrow", compression= "brotli")
